# %%
df = pd.read_csv('wta_matches_2022.csv')

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Box(
    y=df['winner_age'].dropna(),
    name='Mean & SD',
    marker_color='royalblue',
    boxmean='sd' # represent mean and standard deviation
))
fig.show()
fig.save('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 9
#       2 fig.add_trace(go.Box(
#       3     y=df['winner_age'].dropna(),
#       4     name='Mean & SD',
#       5     marker_color='royalblue',
#       6     boxmean='sd' # represent mean and standard deviation
#       7 ))
#       8 fig.show()
# ----> 9 fig.save('')
#
# AttributeError: 'Figure' object has no attribute 'save'
